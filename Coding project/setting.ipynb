# %% [markdown]
# # 라이브러리 설치
# - Install pygame

# %%
# !pip install pygame
# Out:
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    - -------------------------------------- 0.4/10.8 MB 4.6 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/10.8 MB 8.7 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/10.8 MB 10.4 MB/s eta 0:00:01
#    -------- ------------------------------- 2.4/10.8 MB 11.0 MB/s eta 0:00:01
#    --------- ------------------------------ 2.5/10.8 MB 9.9 MB/s eta 0:00:01
#    --------- ------------------------------ 2.6/10.8 MB 8.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.7/10.8 MB 7.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.8/10.8 MB 7.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.0/10.8 MB 6.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.0/10.8 MB 6.3 MB/s eta 0:00:02
# ...
